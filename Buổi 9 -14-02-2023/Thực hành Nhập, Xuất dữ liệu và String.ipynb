# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Please input number:"))
result = n * n
print(f"Square number of {n} is {result}")
# Out:
# Please input number:4
# Square number of 4 is 16

# %%
title = "No.,Fullname,Math,Physics,Chemistry"
data = "1,Nguyen Van A,8.0,9.5,7.4"

# trích xuất ra các điểm số Toán, Lý, Hóa và tính ra 
# điểm trung bình của học sinh Nguyen Van A
# kết quả in ra làm tròn 1 chữ số tập phân

math_score = float(data[15:18])
physics_score = float(data[19:22])
chemistry_score = float(data[23:])

average_score = round((math_score + physics_score + chemistry_score) / 3, 1)

print(f"Math score is {math_score}")
print(f"Physics score is {physics_score}")
print(f"Chemistry score is {chemistry_score}")
print(f"Average score is {average_score}")
# Out:
# Math score is 8.0
# Physics score is 9.5
# Chemistry score is 7.4
# Average score is 8.3
